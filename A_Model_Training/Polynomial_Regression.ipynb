# %% [markdown]
# [Home](../../README.md)
#
# ### Model Training - Linear Regression
#
# Linear regression assumes the data has a linear pattern. If your data does not have a linear pattern you can consider a polynomial regression algorithm that provides a multi (poly) coefficient linear relationship between an independent variable and a dependent variable to predict the outcome of price. We will now Train a Polynomial regression algorithm on the features you have engineered to see how closely we can predict the house prices based off the given and created features
#
# - For our context, it is clear more terms with higher coefficients will required, as a simple linear equation cannot potray the relationship between our features and the target.

# %% [markdown]
# #### Step 1
#
# Load the required dependencies:

# %%
# Import frameworks
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('../style_Matplotlib_charts.mplstyle')
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
import pickle

# %% [markdown]
# #### Step 2
#
# Store the data columns for Polynomial Regression

# %%
# Create a data frame from the csv file
training_data = pd.read_csv('A_training_data_new_2.csv')

x_name = ['value_score', 'tot_rooms', 'ds_float', 'suburb_lat', 'suburb_lng']
y_name = 'Target'
x = np.array(training_data[x_name])
y = np.array(training_data[y_name])

# %% [markdown]
# #### Step 3
#
# Plot the feature `x` and target `y` data on a graph using the column headings as the graph labels.

# %%
if(len(x_name) == 1):
    plt.scatter(x, y, marker='x', c='r')
    plt.title("Predicting House Prices")
    plt.ylabel(f'Training {y_name}')
    plt.xlabel(f'Training {x_name[0]}')
else:
    fig,ax=plt.subplots(1,len(x_name),figsize=(12,3))
    for i in range(len(ax)):
        ax[i].scatter(x[:,i],y, label = 'target')
        ax[i].set_xlabel(x_name[i])
    ax[0].set_ylabel("Target"); ax[0].legend();
    fig.suptitle("Predicting House Prices")
plt.show()

# %% [markdown]
# #### Step 4
#
# Then save an instance of PolynomialFeatures, adjust the 'degree' parameter to suit your model and create the feature using the data in 'x'. (Note a degree of 1 is linear regression, each extra degree adds a coefficient).
#
# Then use the [Scikit-learn](https://scikit-learn.org/stable/) library to instantiate a Machine Learning model class and store it in the `my_model` variable as an object.

# %%
poly = PolynomialFeatures(degree=6, include_bias=False)
poly_features = poly.fit_transform(x)

# Create the model
my_model = LinearRegression()
# Fit the model to the data
my_model.fit(poly_features, y)
# Out:
# LinearRegression()

# %% [markdown]
# - The higher the degree the longer it takes to train the model. This model of degree 8 can take upwards of a minute

# %% [markdown]
# #### Step 5
#
# Plot the features, targets and model (linear regression).

# %%
y_pred = my_model.predict(poly_features)
if(len(x_name) == 1):
    plt.scatter(x, y_pred)
    plt.scatter(x, y, marker='x', c='r')
    plt.title("Predicting House Prices")
    plt.ylabel(f'Training {y_name}')
    plt.xlabel(f'Training {x_name[0]}')
else:
    fig,ax=plt.subplots(1,len(x_name),figsize=(12,3),sharey=True)
    for i in range(len(ax)):
        ax[i].scatter(x[:,i],y, label = 'target')
        ax[i].set_xlabel(x_name[i])
        ax[i].scatter(x[:,i],y_pred,color="orange", label = 'predict')
    ax[0].set_ylabel("Target"); ax[0].legend();
    fig.suptitle("Predicting House Prices")
plt.show()

# %% [markdown]
# #### Step 6
#
# Save the model for testing and validation, since importing the testing and validation for polynomial regression models does not work, testing and validation will be done here

# %%
# save the model to disk
filename = 'A_PR_model_v6.sav'
pickle.dump(my_model, open(filename, 'wb'))

# %% [markdown]
# #### Step 7
#
# Load the polynomial regression model used for testing

# %%
filename = 'A_PR_model_v6.sav'
model_C = pickle.load(open(filename, 'rb'))

# %% [markdown]
# Opening and parsing the test data CSV file, with the specific input features collected

# %% [markdown]
# #### Step 8
#
# - Individually plotting test data features, targets and predictions from the model, on a graph for each input feature, with the purpose of visually evaluating the accuracy of the model

# %%
my_pred = my_model.predict(poly_features)

# plot predictions and targets vs original features    
fig,ax=plt.subplots(1,len(poly_features),figsize=(12,3),sharey=True)
for i in range(len(ax)):
    ax[i].scatter(poly_features[:,i],my_test, label = 'target')
    ax[i].set_xlabel(poly_features[i])
    ax[i].scatter(poly_features[:,i],my_pred,color="orange", label = 'predict')
    ax[i].set_ylabel("Target"); ax[i].legend();
fig.suptitle("Diabetes Disease Progress")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 4
#       1 my_pred = my_model.predict(poly_features)
#       3 # plot predictions and targets vs original features
# ----> 4 fig,ax=plt.subplots(1,len(poly_features),figsize=(12,3),sharey=True)
#       5 for i in range(len(ax)):
#       6     ax[i].scatter(poly_features[:,i],my_test, label = 'target')
#
# File ~/.local/lib/python3.12/site-packages/matplotlib/pyplot.py:1770, in subplots(nrows, ncols, sharex, sharey, squeeze, width_ratios, height_ratios, subplot_kw, gridspec_kw, **fig_kw)
#    1625 """
#    1626 Create a figure and a set of subplots.
#    1627
#    (...)   1767
#    1768 """
#    1769 fig = figure(**fig_kw)
# -> 1770 axs = fig.subplots(nrows=nrows, ncols=ncols, sharex=sharex, sharey=sharey,
#    1771                    squeeze=squeeze, subplot_kw=subplot_kw,
#    1772                    gridspec_kw=gridspec_kw, height_ratios=height_ratios,
#    1773                    width_ratios=width_ratios)
#    1774 return fig, axs
#
# File ~/.local/lib/python3.12/site-packages/matplotlib/figure.py:919, in FigureBase.subplots(self, nrows, ncols, sharex, sharey, squeeze, width_ratios, height_ratios, subplot_kw, gridspec_kw)
#     916     gridspec_kw['width_ratios'] = width_ratios
#     918 gs = self.add_gridspec(nrows, ncols, figure=self, **gridspec_kw)
# --> 919 axs = gs.subplots(sharex=sharex, sharey=sharey, squeeze=squeeze,
#     920                   subplot_kw=subplot_kw)
#     921 return axs
#
# File ~/.local/lib/python3.12/site-packages/matplotlib/gridspec.py:283, in GridSpecBase.subplots(self, sharex, sharey, squeeze, subplot_kw)
#     281         subplot_kw["sharex"] = shared_with[sharex]
#     282         subplot_kw["sharey"] = shared_with[sharey]
# --> 283         axarr[row, col] = figure.add_subplot(
#     284             self[row, col], **subplot_kw)
#     286 # turn off redundant tick labeling
#     287 if sharex in ["col", "all"]:
#
# File ~/.local/lib/python3.12/site-packages/matplotlib/figure.py:768, in FigureBase.add_subplot(self, *args, **kwargs)
#     766         args = tuple(map(int, str(args[0])))
#     767     projection_class, pkw = self._process_projection_requirements(**kwargs)
# --> 768     ax = projection_class(self, *args, **pkw)
#     769     key = (projection_class, pkw)
#     770 return self._add_axes_internal(ax, key)
#
# File ~/.local/lib/python3.12/site-packages/matplotlib/axes/_base.py:726, in _AxesBase.__init__(self, fig, facecolor, frameon, sharex, sharey, label, xscale, yscale, box_aspect, forward_navigation_events, *args, **kwargs)
#     723 self.set_axisbelow(mpl.rcParams['axes.axisbelow'])
#     725 self._rasterization_zorder = None
# --> 726 self.clear()
#     728 # funcs used to format x and y - fall back on major formatters
#     729 self.fmt_xdata = None
#
# File ~/.local/lib/python3.12/site-packages/matplotlib/axes/_base.py:1446, in _AxesBase.clear(self)
#    1444     self.cla()
#    1445 else:
# -> 1446     self.__clear()
#
# File ~/.local/lib/python3.12/site-packages/matplotlib/axes/_base.py:1428, in _AxesBase.__clear(self)
#    1426 share = getattr(self, f"_share{name}")
#    1427 if share is not None:
# -> 1428     getattr(self, f"share{name}")(share)
#    1429 else:
#    1430     # Although the scale was set to linear as part of clear,
#    1431     # polar requires that _set_scale is called again
#    1432     if self.name == "polar":
#
# File ~/.local/lib/python3.12/site-packages/matplotlib/axes/_base.py:1304, in _AxesBase.sharey(self, other)
#    1302 self.yaxis.minor = other.yaxis.minor  # locator and formatter.
#    1303 y0, y1 = other.get_ylim()
# -> 1304 self.set_ylim(y0, y1, emit=False, auto=other.get_autoscaley_on())
#    1305 self.yaxis._scale = other.yaxis._scale
#
# File ~/.local/lib/python3.12/site-packages/matplotlib/axes/_base.py:4046, in _AxesBase.set_ylim(self, bottom, top, emit, auto, ymin, ymax)
#    4044         raise TypeError("Cannot pass both 'top' and 'ymax'")
#    4045     top = ymax
# -> 4046 return self.yaxis._set_lim(bottom, top, emit=emit, auto=auto)
#
# File ~/.local/lib/python3.12/site-packages/matplotlib/axis.py:1251, in Axis._set_lim(self, v0, v1, emit, auto)
#    1249 self.set_view_interval(v0, v1, ignore=True)
#    1250 # Mark viewlims as no longer stale without triggering an autoscale.
# -> 1251 for ax in self._get_shared_axes():
#    1252     ax._stale_viewlims[name] = False
#    1253 self._set_autoscale_on(auto)
#
# File ~/.local/lib/python3.12/site-packages/matplotlib/axis.py:704, in Axis._get_shared_axes(self)
#     701 def _get_shared_axes(self):
#     702     """Return Grouper of shared Axes for current axis."""
#     703     return self.axes._shared_axes[
# --> 704         self._get_axis_name()].get_siblings(self.axes)
#
# File ~/.local/lib/python3.12/site-packages/matplotlib/cbook.py:874, in Grouper.get_siblings(self, a)
#     872 """Return all of the items joined with *a*, including itself."""
#     873 siblings = self._mapping.get(a, [a])
# --> 874 return sorted(siblings, key=self._ordering.get)
#
# File /usr/local/python/3.12.1/lib/python3.12/_weakrefset.py:70, in WeakSet.__iter__(self)
#      66 item = itemref()
#      67 if item is not None:
#      68     # Caveat: the iterator will keep a strong reference to
#      69     # `item` until it is resumed or closed.
# ---> 70     yield item
#
# KeyboardInterrupt:

# %%
test_score = model_C.score(mx_test, my_test)
print(f'Training data score: {test_score}')

# %% [markdown]
# - This score is far lower than the multivariable score, so it is clear that polynomial regression is not the optimal algorithm and no further testing is required, and will not be used on the second model
